# %%
import streamlit as st
import pandas as pd
import joblib

# Load trained model
model = joblib.load("housing_price_model.pkl")

# Page title
st.title("Sydney Housing Price Prediction")

st.write(
    "Enter the property details below to estimate the sale price."
)

# User inputs
suburb = st.selectbox(
    "Suburb",
    ["Beverly Hills", "Concord", "Castle Hill"]
)

property_type = st.selectbox(
    "Property Type",
    ["House", "Apartment", "Villa", "Semi-detached"]
)

bedrooms = st.number_input(
    "Number of Bedrooms",
    min_value=1,
    max_value=10,
    value=3
)

bathrooms = st.number_input(
    "Number of Bathrooms",
    min_value=1,
    max_value=10,
    value=2
)

# Calculate engineered feature
total_rooms = bedrooms + bathrooms

# Prediction button
if st.button("Predict Sale Price"):

    input_data = pd.DataFrame({
        "suburb": [suburb],
        "property_type": [property_type],
        "bedrooms": [bedrooms],
        "bathrooms": [bathrooms],
        "total_rooms": [total_rooms]
    })

    prediction = model.predict(input_data)[0]

    st.success(
        f"Estimated Sale Price: ${prediction:,.0f}"
    )
# Out:
# 2026-09-17 23:17:06.590 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.644
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-09-17 23:17:06.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.646 Session state does not function when running a script without `streamlit run`
# 2026-09-17 23:17:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-17 23:17:06.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
